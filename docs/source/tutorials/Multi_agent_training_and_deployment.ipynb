# %% [markdown]
# # MARL training and deployment
#
# The following notebook provides an introduction to training several RL agents with the multi-agent proximal policy optimization (MAPPO) algorithm. We use CommonPower to create a simulation of a power system, within which one node (corresponding to a multi-family household) is controlled by the RL agent. Since RL does not naturally allow considering constraints, such as a minimum state of charge of a battery, we have implemented a safety layer that is wrapped around the RL agent. It extracts all necessary constraints from the power system model and checks whether a control action suggested by the agent is safe. If necessary, the safety layer adjust the action, before passing it on to the simulation. The agent then receives a feedback informing it about the adjustment of its action.
#
# Within this notebook, you will learn how to
# - use CommonPower to import a network topology from pandapower
# - add components like energy storage systems to such a network
# - set up a decentralized control scheme with multiple RL agents,
# - assign nodes to these agents,
# - train the RL agents, and
# - monitor the training process using Tensorboard.
#
# ## Before getting started
# 1. Make sure you install all necessary requirements following the `Readme.txt`
# 2. Optional (only if you want to experiment with tracking training using Weights&Biases): Sign up for the academic version of Weights&Biases [here](https://wandb.ai/site/research).
#
# ## Important ressources for further information
# ### Short introduction to RL
# If you have never worked with RL before, we recommend reading the [OpenAI Spinning Up](https://spinningup.openai.com/en/latest/spinningup/rl_intro.html) introduction of RL.
# ### MAPPO implementation
# We use a fork of the MAPPO algorithm from the [on-policy repository](https://github.com/TUMcps/on-policy).
# ### Tensorboard
# [Tensorboard](https://www.tensorflow.org/tensorboard/get_started) can be used to track training of any kind of network.
# ### Weights&Biases
# Weights&Biases (W&B) is an alternative to Tensorboard with very nice visualizations and some advanced options. It helps you keep an overview of your experiments and compare different hyperparameter settings. Find more information in their [documentation](https://docs.wandb.ai/quickstart)

# %%
import pathlib
from numpy.random import uniform, choice
from commonpower.models.components import *
from commonpower.models.busses import *
from commonpower.models.lines import *
from commonpower.models.powerflow import *
from commonpower.extensions.factories import Factory, Sampler
from commonpower.data_forecasting import *
from commonpower.utils.param_initialization import RangeInitializer
from commonpower.control.controllers import *
from commonpower.control.safety_layer.safety_layers import *
from commonpower.control.logging.loggers import *
from commonpower.control.runners import *
from commonpower.control.wrappers import *

from commonpower.extensions.network_import import PandaPowerImporter
import pandapower.networks as pn
# Out:
# 2023-08-18 16:23:09.539546: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-18 16:23:09.631722: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-18 16:23:10.030723: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/hannah/anaconda3/envs/commongrid/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-08-18 16:23:10.030763: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/hannah/anaconda3/envs/commongrid/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-08-18 16:23:10.030766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## System set-up
# First, we have to define the energy system the RL agents should interact with. We will use a small network that we import from pandapower to get the network topology and characteristics (line admittances etc.). Then, we will add components to the load buses of this network.

# %%
# number of control steps
horizon = 24

# path to data profiles
current_path = pathlib.Path().absolute()
data_path = current_path / 'data'
data_path = data_path.resolve()

ds1a = CSVDataSource(
    data_path / '1-LV-rural2--1-sw' / 'LoadProfile.csv',
    delimiter=";",
    datetime_format="%d.%m.%Y %H:%M",
    rename_dict={"time": "t", "H0-A_pload": "p", "H0-A_qload": "q"},
    auto_drop=True,
    resample=timedelta(minutes=60)).apply_to_column("p", lambda x: 10 * x).apply_to_column("q", lambda x: 0.0)

ds1b = CSVDataSource(
    data_path / '1-LV-rural2--1-sw' / 'LoadProfile.csv',
    delimiter=";",
    datetime_format="%d.%m.%Y %H:%M",
    rename_dict={"time": "t", "H0-A_pload": "p", "H0-A_qload": "q"},
    auto_drop=True,
    resample=timedelta(minutes=60)
).apply_to_column("p", lambda x: 10 * x).shift_time_series(timedelta(hours=24)).apply_to_column("q", lambda x: 0.0)

ds1c = CSVDataSource(
    data_path / '1-LV-rural2--1-sw' / 'LoadProfile.csv',
    delimiter=";",
    datetime_format="%d.%m.%Y %H:%M",
    rename_dict={"time": "t", "H0-B_pload": "p", "H0-B_qload": "q"},
    auto_drop=True,
    resample=timedelta(minutes=60)).apply_to_column("p", lambda x: 10 * x).apply_to_column("q", lambda x: 0.0)

ds2 = CSVDataSource(
    data_path / 'spot_prices_dk.csv',
    delimiter=";",
    decimal=",",
    datetime_format="%Y-%m-%d %H:%M",
    rename_dict={"HourUTC": "t", "SpotPriceEUR": "psi"},
    auto_drop=True,
    resample=timedelta(minutes=60)).apply_to_column("psi", lambda x: x / 1000)  # prices are EUR/MWh

ds3a = CSVDataSource(
    data_path / '1-LV-rural2--1-sw' / 'RESProfile.csv',
    delimiter=";",
    datetime_format="%d.%m.%Y %H:%M",
    rename_dict={"time": "t", "PV3": "p"},
    auto_drop=True,
    resample=timedelta(minutes=60)).apply_to_column("p", lambda x: -10 * x)

ds3b = CSVDataSource(
    data_path / '1-LV-rural2--1-sw' / 'RESProfile.csv',
    delimiter=";",
    datetime_format="%d.%m.%Y %H:%M",
    rename_dict={"time": "t", "PV7": "p"},
    auto_drop=True,
    resample=timedelta(minutes=60)).apply_to_column("p", lambda x: -10 * x)

dp1a = DataProvider(ds1a, NoisyForecaster(frequency=timedelta(minutes=60), horizon=timedelta(hours=horizon)))
dp1b = DataProvider(ds1b, NoisyForecaster(frequency=timedelta(minutes=60), horizon=timedelta(hours=horizon)))
dp1c = DataProvider(ds1c, NoisyForecaster(frequency=timedelta(minutes=60), horizon=timedelta(hours=horizon)))
dp2 = DataProvider(ds2, NoisyForecaster(frequency=timedelta(minutes=60), horizon=timedelta(hours=horizon)))
dp3a = DataProvider(ds3a, NoisyForecaster(frequency=timedelta(minutes=60), horizon=timedelta(hours=horizon)))
dp3b = DataProvider(ds3b, NoisyForecaster(frequency=timedelta(minutes=60), horizon=timedelta(hours=horizon)))

# We are using DC powerflow 
power_flow_mode = DCPowerFlowModel()

rand_seed = 888

# %% [markdown]
# We use a Factory so we do not have to manually add components to each load bus.

# %%
# Individual system (decentralized control)
np.random.seed(rand_seed)

ind_factory = Factory()

ind_factory.set_bus_template(
    RTPricedBusLinear,
    meta_config={
        "p": Sampler(uniform, low=[-1e3, 1e3], high=[-1e3, 1e3]),
        "q": Sampler(uniform, low=[-1e3, 1e3], high=[-1e3, 1e3]),
        "v": Sampler(uniform, low=[0.9, 1.1], high=[0.9, 1.1]),
        "d": Sampler(uniform, low=[-15, 15], high=[-15, 15])
    },
    data_providers=[dp2]
)

# add components to factory
# Load: base load of the household (corresponds to fridge, dishwasher, washing machine, etc.)
ind_factory.add_component_template(Load, probability=1., data_providers=[Sampler(choice, a=[dp1a, dp1b, dp1c])])

# RenewableGen: renewable generation (e.g., PV)
ind_factory.add_component_template(
    RenewableGen,
    probability=.5,
    meta_config={
        "p": Sampler(uniform, low=[-7, 0], high=[-7, 0]),
        "q": Sampler(uniform, low=[0, 0], high=[0, 0])
    },
    data_providers=[Sampler(choice, a=[dp3a, dp3b])]
)

# ESSLinear: energy storage system (e.g., battery) with highly simplified dynamics  (to reduce computation time)
ess_capa = 10  # kwh
ind_factory.add_component_template(
    ESSLinear,
    probability=0.5,
    meta_config={
        'rho': 0.1,
        'p': Sampler(uniform, low=[-5, 5], high=[-5, 5]),
        'q': Sampler(uniform, low=[0, 0], high=[0, 0]),
        'etac': 0.95,
        'etad': 0.95,
        'etas': 0.99,
        'soc': Sampler(uniform, low=[0.2 * ess_capa, 0.8 * ess_capa], high=[0.2 * ess_capa, 0.8 * ess_capa]),
        "soc_init": [RangeInitializer, {"lb": Sampler(uniform, low=0.3 * ess_capa, high=0.3 * ess_capa),
                                        "ub": Sampler(uniform, low=0.5 * ess_capa, high=0.5 * ess_capa)}]
    }
)

# %% [markdown]
# Finally, we can load the network topology from pandapower and create a power system using the factory.

# %%
# initialize system
net = pn.create_kerber_landnetz_kabel_2()
ind_sys = PandaPowerImporter().import_net(
    net=net,
    power_flow_model=power_flow_mode,
    node_factory=ind_factory,
    restrict_factory_to="loadbus"
)

n999 = ExternalGrid("ExternalGrid")

# set node 1 (main_busbar) as external grid connection, i.e. trading node to import unbalanced quantities of power
ind_sys.add_node(n999, at_index=1)

# update the respective lines
ind_sys.lines[0].src = n999
ind_sys.lines[24].src = n999

# remove line from ext to main busbar
ind_sys.lines.pop(-1)
# remove node 0
ind_sys.nodes.pop(0)
# Show the system set-up
ind_sys.pprint()
# Out:
# SYSTEM OVERVIEW
#
# Nodes:
#    n1 (ExternalGrid): ExternalGrid
#    n2 (Bus): MUF_1_1
#    n3 (RTPricedBusLinear): loadbus_1_1
#       n3.d30 (Load): Load
#       n3.el31 (ESSLinear): ESSLinear
#    n4 (Bus): KV_1_2
#    n5 (RTPricedBusLinear): loadbus_1_2
#       n5.d50 (Load): Load
#       n5.r51 (RenewableGen): RenewableGen
#       n5.el52 (ESSLinear): ESSLinear
#    n6 (Bus): MUF_1_3
#    n7 (RTPricedBusLinear): loadbus_1_3
#       n7.d70 (Load): Load
#       n7.r71 (RenewableGen): RenewableGen
#       n7.el72 (ESSLinear): ESSLinear
#    n8 (Bus): KV_1_4
#    n9 (RTPricedBusLinear): loadbus_1_4
#       n9.d90 (Load): Load
#       n9.r91 (RenewableGen): RenewableGen
#       n9.el92 (ESSLinear): ESSLinear
#    n10 (Bus): MUF_1_5
#    n11 (RTPricedBusLinear): loadbus_1_5
#       n11.d110 (Load): Load
#       n11.r111 (RenewableGen): RenewableGen
#    n12 (Bus): KV_1_6
#    n13 (RTPricedBusLinear): loadbus_1_6
#       n13.d130 (Load): Load
#       n13.r131 (RenewableGen): RenewableGen
#       n13.el132 (ESSLinear): ESSLinear
#    n14 (Bus): MUF_1_7
#    n15 (RTPricedBusLinear): loadbus_1_7
#       n15.d150 (Load): Load
#       n15.r151 (RenewableGen): RenewableGen
#       n15.el152 (ESSLinear): ESSLinear
#    n16 (Bus): KV_1_8
#    n17 (RTPricedBusLinear): loadbus_1_8
#       n17.d170 (Load): Load
#       n17.el171 (ESSLinear): ESSLinear
#    n18 (Bus): MUF_1_9
#    n19 (RTPricedBusLinear): loadbus_1_9
#       n19.d190 (Load): Load
#       n19.el191 (ESSLinear): ESSLinear
#    n20 (Bus): KV_1_10
#    n21 (RTPricedBusLinear): loadbus_1_10
#       n21.d210 (Load): Load
#       n21.r211 (RenewableGen): RenewableGen
#       n21.el212 (ESSLinear): ESSLinear
#    n22 (Bus): MUF_1_11
#    n23 (RTPricedBusLinear): loadbus_1_11
#       n23.d230 (Load): Load
#       n23.r231 (RenewableGen): RenewableGen
#       n23.el232 (ESSLinear): ESSLinear
#    n24 (Bus): KV_1_12
#    n25 (RTPricedBusLinear): loadbus_1_12
#       n25.d250 (Load): Load
#    n26 (Bus): MUF_2_1
#    n27 (RTPricedBusLinear): loadbus_2_1
#       n27.d270 (Load): Load
#       n27.r271 (RenewableGen): RenewableGen
#    n28 (Bus): KV_2_2
#    n29 (RTPricedBusLinear): loadbus_2_2
#       n29.d290 (Load): Load
#       n29.r291 (RenewableGen): RenewableGen
#
# Lines:
#    lb_n1_n2: n1 -- n2
#    lb_n2_n3: n2 -- n3
#    lb_n2_n4: n2 -- n4
#    lb_n4_n5: n4 -- n5
#    lb_n4_n6: n4 -- n6
#    lb_n6_n7: n6 -- n7
#    lb_n6_n8: n6 -- n8
#    lb_n8_n9: n8 -- n9
#    lb_n8_n10: n8 -- n10
#    lb_n10_n11: n10 -- n11
#    lb_n10_n12: n10 -- n12
#    lb_n12_n13: n12 -- n13
#    lb_n12_n14: n12 -- n14
#    lb_n14_n15: n14 -- n15
#    lb_n14_n16: n14 -- n16
#    lb_n16_n17: n16 -- n17
#    lb_n16_n18: n16 -- n18
#    lb_n18_n19: n18 -- n19
#    lb_n18_n20: n18 -- n20
#    lb_n20_n21: n20 -- n21
#    lb_n20_n22: n20 -- n22
#    lb_n22_n23: n22 -- n23
#    lb_n22_n24: n22 -- n24
#    lb_n24_n25: n24 -- n25
#    lb_n1_n26: n1 -- n26
#    lb_n26_n27: n26 -- n27
#    lb_n26_n28: n26 -- n28
#    lb_n28_n29: n28 -- n29
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):
# /home/hannah/.local/lib/python3.8/site-packages/pandapower/auxiliary.py:272: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item, dtype in list(dtypes.iteritems()):

# %% [markdown]
# ## MARL Training
# Now that we have the system set-up, we can add controllers to all buses that have controllable components. In this case, this means all buses with a battery storage system (ESSLinear).
#
# There are many hyperparameters for MARL training. The most important ones are the `num_env_steps`, which determines the length of the training, and the `episode_length`, which determines how many days of data we collect before updating the policies. This should be a multiple of the `horizon` parameter.

# %%
# algorithm configuration
all_args_dict = {
    "algorithm_name": "mappo",
    "seed": 1,
    "cuda": False,
    "cuda_deterministic": True,
    "n_training_threads": 1,
    "n_rollout_threads": 1,
    "n_eval_rollout_threads": 1,
    "num_env_steps": 1200 * horizon,
    "episode_length": 3 * horizon,
    "share_policy": False,
    "use_centralized_V": True,
    "hidden_size": 64,
    "layer_N": 1,
    "use_ReLU": True,
    "use_popart": False,
    "use_valuenorm": False,
    "use_feature_normalization": True,
    "use_orthogonal": True,
    "gain": 0.01,
    "use_naive_recurrent_policy": False,
    "use_recurrent_policy": True,
    "recurrent_N": 1,
    "data_chunk_length": 10,
    "lr": 0.0005,
    "critic_lr": 0.0005,
    "opti_eps": 1e-05,
    "weight_decay": 0,
    "ppo_epoch": 5,
    "use_clipped_value_loss": True,
    "clip_param": 0.2,
    "num_mini_batch": 3,
    "entropy_coef": 0.01,
    "value_loss_coef": 1,
    "use_max_grad_norm": True,
    "max_grad_norm": 0.5,
    "use_gae": True,
    "gamma": 0.99,
    "gae_lambda": 0.95,
    "use_proper_time_limits": False,
    "use_huber_loss": True,
    "use_value_active_masks": True,
    "use_policy_active_masks": True,
    "huber_delta": 10.0,
    "use_linear_lr_decay": False,
    "log_interval": 1,
    "use_eval": False,
    "eval_interval": 25,
    "eval_episodes": 32,
    "ifi": 0.1,
    # args from Commonpower
    "safety_penalty": 2.0
}

# %%
# add individual RL controllers
for i in range(len(ind_sys.nodes)):
    # will also add a controller to households which do not have inputs (e.g., households with only a Load component),
    # but these are disregarded when the system is initialized
    _ = RLControllerMA(
        name=f"agent{i}",
        safety_layer=ActionProjectionSafetyLayer(penalty_factor=all_args_dict["safety_penalty"])
    ).add_entity(ind_sys.nodes[i])

# %% [markdown]
# For logging the training, you can use either just tensorboard or Weights&Biases. For tensorboard, you do not have to register. For W&B, you need to get an account, create a team and then log in, which is why we use tensorboard as a default. However, we provide the code for using W&B and you can just uncomment it if you want to try that. However, you will have to change the `entity_name` to the name of your team.

# %%
# logging using Tensorboard
logger = MARLTensorboardLogger(
    log_dir="./test_run/",
    callback=MARLBaseCallback
)
# logging using WandB
#logger = MARLWandBLogger(
#    log_dir="./test_run/",
#    entity_name="srl4ps",  # change to your team name!
#    project_name="commonpower",
#    alg_config=all_args_dict,
#    callback=MARLWandBCallback
#)

# %% [markdown]
# The actual training will happen in the next cell. WARNING: It will take several hours until the training fully converges. If you just want to get an idea of what the training process would look like, reduce the `num_env_steps` in the `all_args_dict` above. You can also skip the training and go directly to the benchmarking, in which case you will use agents that we have pre-trained for you.

# %%
runner = MAPPOTrainer(
    sys=ind_sys,
    global_controller=OptimalController('global'),
    wrapper=MultiAgentWrapper,
    alg_config=all_args_dict,
    seed=all_args_dict['seed'],
    logger=logger
)
runner.run()
# Out:
# choose to use cpu...
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# /home/hannah/.local/lib/python3.8/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float64
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /home/hannah/.local/lib/python3.8/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Total episodes: 1
# ------------------------------------------
# | agent0/                    |           |
# |    average_episode_rewards | -742      |
# |    ep_corrections_mean     | 16.3      |
# |    ep_penalty_mean         | 29.9      |
# |    ep_rew_without_pen_mean | -24.2     |
# |    explained_variance      | 2.05e-05  |
# |    policy_loss             | -0.0123   |
# |    value_loss              | 3.88e+03  |
# | agent1/                    |           |
# |    average_episode_rewards | -635      |
# |    ep_corrections_mean     | 15        |
# |    ep_penalty_mean         | 25.9      |
# |    ep_rew_without_pen_mean | -12.3     |
# |    explained_variance      | -0.000182 |
# |    policy_loss             | -0.0329   |
# |    value_loss              | 3.83e+03  |
# | agent2/                    |           |
# |    average_episode_rewards | -782      |
# |    ep_corrections_mean     | 17.3      |
# |    ep_penalty_mean         | 32.1      |
# |    ep_rew_without_pen_mean | -11.5     |
# |    explained_variance      | 1.92e-05  |
# |    policy_loss             | -0.0168   |
# |    value_loss              | 3.67e+03  |
# | agent3/                    |           |
# |    average_episode_rewards | -595      |
# |    ep_corrections_mean     | 16.3      |
# |    ep_penalty_mean         | 24.2      |
# |    ep_rew_without_pen_mean | -14.5     |
# |    explained_variance      | 0.000124  |
# |    policy_loss             | -0.0159   |
# |    value_loss              | 3.63e+03  |
# | agent4/                    |           |
# |    average_episode_rewards | -495      |
# |    ep_corrections_mean     | 15        |
# |    ep_penalty_mean         | 20.7      |
# |    ep_rew_without_pen_mean | 2.91      |
# |    explained_variance      | -0.000156 |
# |    policy_loss             | -0.0124   |
# |    value_loss              | 2.82e+03  |
# | agent5/                    |           |
# |    average_episode_rewards | -621      |
# |    ep_corrections_mean     | 17        |
# |    ep_penalty_mean         | 25.4      |
# |    ep_rew_without_pen_mean | -11.6     |
# |    explained_variance      | -0.000175 |
# |    policy_loss             | -0.0215   |
# |    value_loss              | 3.35e+03  |
# | agent6/                    |           |
# |    average_episode_rewards | -559      |
# |    ep_corrections_mean     | 14        |
# |    ep_penalty_mean         | 22.3      |
# |    ep_rew_without_pen_mean | -24.2     |
# |    explained_variance      | -0.000149 |
# |    policy_loss             | -0.014    |
# |    value_loss              | 3.2e+03   |
# | agent7/                    |           |
# |    average_episode_rewards | -666      |
# |    ep_corrections_mean     | 15.3      |
# |    ep_penalty_mean         | 26.8      |
# |    ep_rew_without_pen_mean | -23.6     |
# |    explained_variance      | 4.7e-05   |
# |    policy_loss             | -0.0146   |
# |    value_loss              | 3.55e+03  |
# | agent8/                    |           |
# |    average_episode_rewards | -549      |
# |    ep_corrections_mean     | 15        |
# |    ep_penalty_mean         | 22.2      |
# |    ep_rew_without_pen_mean | -14.7     |
# |    explained_variance      | 5.5e-05   |
# |    policy_loss             | -0.0213   |
# |    value_loss              | 2.71e+03  |
# | agent9/                    |           |
# |    average_episode_rewards | -687      |
# |    ep_corrections_mean     | 15.7      |
# |    ep_penalty_mean         | 28.1      |
# |    ep_rew_without_pen_mean | -12       |
# |    explained_variance      | -1.93e-05 |
# |    policy_loss             | -0.0165   |
# |    value_loss              | 3.8e+03   |
# | time/                      |           |
# |    fps                     | 1         |
# |    total_timesteps         | 72        |
# ------------------------------------------

# %% [markdown]
# ### Training visualization
# If you used the TensorBoardLogger, you can plot the training metrics using the notebook magic of tensorboard. The metrics are sorted by agent. The most interesting metrics for us are the __average_episode_rewards__, the __ep_penalty_mean__, and the __value_loss__. Think about what these charts tell you and discuss it!

# %%
# %load_ext tensorboard
# %tensorboard --logdir test_run
# Out:
#       <iframe id="tensorboard-frame-1027c4d1c386bbc4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1027c4d1c386bbc4");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Benchmarking MARL and decentralized optimal control
# We want to benchmark our trained agents against decentralized optimal control.

# %%
# parameters for deployment
n_deployment_steps = 48
eval_seed = 5

# %% [markdown]
# ### Decentralized optimal control

# %%
# add optimal controllers (will overwrite the RL controllers)
for i in range(len(ind_sys.nodes)):
    # will also add a controller to households which do not have inputs (e.g., households with only a Load component), 
    # but these are disregarded when the system is initialized
    _ = OptimalController(f"agent{i}").add_entity(ind_sys.nodes[i])
# Out:
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n1 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n2 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n3 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n3.d30 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n3.el31 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n4 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n5 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n5.d50 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n5.r51 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n5.el52 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n6 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n7 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n7.d70 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n7.r71 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n7.el72 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n8 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n9 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n9.d90 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n9.r91 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n9.el92 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n10 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n11 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n11.d110 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n11.r111 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n12 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n13 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n13.d130 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n13.r131 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n13.el132 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n14 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n15 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n15.d150 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n15.r151 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n15.el152 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n16 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n17 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n17.d170 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n17.el171 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n18 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n19 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n19.d190 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n19.el191 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n20 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n21 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n21.d210 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n21.r211 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n21.el212 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n22 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n23 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n23.d230 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n23.r231 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n23.el232 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n24 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n25 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n25.d250 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n26 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n27 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n27.d270 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n27.r271 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n28 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:211: UserWarning: Node n29 already has a controller
#   warnings.warn(f"Node {entity.id} already has a controller")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n29.d290 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")
# /home/hannah/Documents/Code/commonpower/commonpower/control/controllers.py:232: UserWarning: Node n29.r291 already has a controller!
#   warnings.warn(f"Node {child.id} already has a controller!")

# %%
ind_sys_history = ModelHistory([ind_sys])
runner = DeploymentRunner(sys=ind_sys, global_controller=OptimalController("global"),
                          seed=eval_seed, history=ind_sys_history, continuous_control=True)
runner.run(n_steps=n_deployment_steps)
# Out:
# 100%|███████████████████████████████████████████| 48/48 [00:45<00:00,  1.06it/s]

# %% [markdown]
# ### MARL deployment
# After training the agents, we will showcase how to load them.

# %%
# retrieve information which agent controlled which nodes
top_level_nodes = []
for ctrl in ind_sys.controllers.values():
    top_level_nodes.append(ctrl.top_level_nodes)
    
# deployment of trained agents
load_path = "./saved_models/test_model/"  # In case you used W&B for logging, the models will be saved in "./test_run/models/og1te5k4", where you have to replace the last part with the respective run ID. 
agents = []
for i in range(len(ind_sys.controllers)):
    agent_i = RLControllerMA(
        name=f"agent{i}",
        safety_layer=ActionProjectionSafetyLayer(penalty_factor=all_args_dict["safety_penalty"]),
        pretrained_policy_path=load_path+f"/agent{i}"
    ).add_entity(top_level_nodes[i][0])
    agents.append(agent_i)

# %%
ind_sys_history_marl = ModelHistory([ind_sys])
runner = DeploymentRunner(sys=ind_sys, global_controller=OptimalController("global"), alg_config=all_args_dict,
                          wrapper=MultiAgentWrapper, history=ind_sys_history_marl, seed=eval_seed, continuous_control=True)
runner.run(n_steps=n_deployment_steps)
# Out:
# /home/hannah/.local/lib/python3.8/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float64
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /home/hannah/.local/lib/python3.8/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
# You are choosing to use MAPPO, we set use_recurrent_policy & use_naive_recurrent_policy to be False
#  46%|███████████████████▋                       | 22/48 [00:21<00:24,  1.08it/s]

# %% [markdown]
# ### Comparison of total cost

# %%
# We compare controllers by tracking the realized cost until the last timestep. 
# The cost of the last timestep is the accumulated cost of the projected horizon. 
# Since the projection is computed by the system's "internal" solver, which is by definition optimal wrt. to the system's cost function, this represents the "best case" cost (subject to the forecaster).
# This makes sure that costs realized in the future, e.g. by discharing batteries, is considered in the comparison.

def get_adjusted_cost(hist: ModelHistory, sys: System):
    costs = hist.filter_for_entities(sys, False).filter_for_element_names("cost").history
    output = [c[1]["cost"][0] for c in costs]
    terminal_cost = np.sum(costs[-1][1]["cost"])
    output[-1] = terminal_cost
    return output

decentralized_cost = get_adjusted_cost(ind_sys_history, ind_sys)
decentralized_cost_rl = get_adjusted_cost(ind_sys_history_marl, ind_sys)
print(f"decentralized_cost: {sum(decentralized_cost)}")
print(f"decentralized_cost_rl: {sum(decentralized_cost_rl)}")

# %% [markdown]
# ### Comparison of controllers for one day
# Next, we will show an example of the difference in behavior of an RL controller and an optimal controller for a given day and one household.

# %%
 # day to use
start = "2016-08-29 00:00:00"
end = "2016-08-29 23:00:00"

# %%
price_history = ind_sys_history.filter_for_entities(ind_sys.nodes[4]).filter_for_time_period(start,end).filter_for_element_names(["psi"]).filter_for_time_index().history
prices = [t[1]['n5.psi'] for t in price_history]
time_stamps = [t[0] for t in price_history]
cost_history = ind_sys_history.filter_for_entities(ind_sys.nodes[4]).filter_for_time_period(start,end).filter_for_element_names(["cost"]).filter_for_time_index().history
costs = [t[1]['n5.cost'] for t in cost_history]
soc_history = ind_sys_history.filter_for_entities(ind_sys.nodes[4].nodes[2]).filter_for_time_period(start,end).filter_for_element_names(["soc"]).filter_for_time_index().history
soc = [t[1]["n5.el52.soc"] for t in soc_history]
soc_history_rl = ind_sys_history_marl.filter_for_entities(ind_sys.nodes[4].nodes[2]).filter_for_time_period(start,end).filter_for_element_names(["soc"]).filter_for_time_index().history
soc_rl = [t[1]["n5.el52.soc"] for t in soc_history_rl]

# %%
import matplotlib.pyplot as plt
def make_results_plot(time_stamps, prices, soc_oc, soc_rl):
    fig, ax = plt.subplots()
    ax.plot(time_stamps, prices, color='blue', label='Spot market prices')
    ax.tick_params(axis='y', labelcolor='blue')
    ax.tick_params(axis='x', rotation=45)
    ax2 = ax.twinx()
    ax2.plot(time_stamps, soc_oc, color='orange', label='SoC Optimal Controller')
    ax2.tick_params(axis='y', labelcolor='orange')
    ax3 = ax.twinx()
    ax3.plot(time_stamps, soc_rl, color='green', label='SoC RL Controller')
    ax3.tick_params(axis='y', labelcolor='green')
    ax3.spines['right'].set_position(('outward', 60))
    fig.legend()
    
    plt.show()

make_results_plot(time_stamps, prices, soc, soc_rl)

# %% [markdown]
# As you can see, the optimal controller is far more aggressive than the RL controller. This is probably due to the safety constraints, since the agent learned not to get close to the limits of the battery. It gives a hint on why the optimal controller performs better in the overall cost.
